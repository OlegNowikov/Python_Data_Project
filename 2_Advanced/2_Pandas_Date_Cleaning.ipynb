# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
median_salary_year = df['salary_year_avg'].median()
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_filled.loc[28, 'salary_year_avg':'salary_hour_avg']
# Out:
# salary_year_avg    109500.0
# salary_hour_avg       45.98
# Name: 28, dtype: object

# %%
df_unique = df_filled
df_unique = df_unique.drop_duplicates()
df_unique = df_unique.drop_duplicates(subset=['job_title', 'company_name'])
len(df_filled) - len(df_unique)
# Out:
# 277699

# %%
df.sample(10)
# Out:
#           job_title_short                                          job_title  \
# 135025   Business Analyst                     Business Analytics Coordinator
# 538285     Data Scientist                                     Data Scientist
# 643928     Cloud Engineer                        Lead Engineer, Transmission
# 293326      Data Engineer                  Staff Data Engineer (Chicago, IL)
# 483321       Data Analyst                                Junior Data Analyst
# 531930  Software Engineer                                    DevOps Engineer
# 674784       Data Analyst                                   Web Data Analyst
# 607379     Data Scientist  Data Scientist Standard II / Data Analyst & Sc...
# 577553       Data Analyst                         Data Analyst (SQL & MySQL)
# 757538      Data Engineer       Data Engineer-6-month contract-UK Government
#
#                                       job_location                 job_via  \
# 135025                             Santiago, Chile               via BeBee
# 538285                              Menlo Park, CA               via BeBee
# 643928                         Riyadh Saudi Arabia               via BeBee
# 293326                                 Chicago, IL    via Built In Chicago
# 483321                              United Kingdom            via LinkedIn
# 531930                   East London, South Africa  via BeBee South Africa
# 674784                            Cockeysville, MD           via Hitmarker
# 607379                              Washington, DC            via LinkedIn
# 577553  Naples, Metropolitan City of Naples, Italy            via LinkedIn
# 757538                          Basel, Switzerland       via BeBee Schweiz
#
#        job_schedule_type  job_work_from_home            search_location  \
# 135025         Full-time               False                      Chile
# 538285         Full-time               False  California, United States
# 643928         Full-time               False               Saudi Arabia
# 293326         Full-time               False  California, United States
# 483321         Full-time               False             United Kingdom
# 531930         Full-time               False               South Africa
# 674784         Full-time               False    New York, United States
# 607379        Contractor               False    New York, United States
# 577553         Full-time               False                      Italy
# 757538         Part-time               False                Switzerland
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 135025 2023-09-06 08:37:22                  False                 False
# 538285 2023-08-29 19:05:55                  False                 False
# 643928 2023-11-26 12:34:07                  False                 False
# 293326 2023-02-14 17:06:17                  False                 False
# 483321 2023-02-17 14:21:03                   True                 False
# 531930 2023-08-23 19:12:58                  False                 False
# 674784 2023-01-13 10:00:29                  False                 False
# 607379 2023-01-30 09:00:48                  False                 False
# 577553 2023-03-20 09:22:33                  False                 False
# 757538 2023-02-15 21:17:55                   True                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 135025           Chile        None         115000.0            45.98
# 538285   United States        None         115000.0            45.98
# 643928    Saudi Arabia        None         115000.0            45.98
# 293326   United States        year         192500.0            45.98
# 483321  United Kingdom        None         115000.0            45.98
# 531930    South Africa        None         115000.0            45.98
# 674784   United States        None         115000.0            45.98
# 607379   United States        None         115000.0            45.98
# 577553           Italy        None         115000.0            45.98
# 757538     Switzerland        None         115000.0            45.98
#
#                           company_name  \
# 135025               Johnson & Johnson
# 538285                            Meta
# 643928                       ICM Group
# 293326             Integral Ad Science
# 483321                        Miniclip
# 531930  Mercedes-Benz South Africa Ltd
# 674784                   ZeniMax Media
# 607379                            Dice
# 577553                           Tecno
# 757538              NonStop Consulting
#
#                                                job_skills  \
# 135025      ['sql', 'python', 'r', 'power bi', 'tableau']
# 538285                             ['sql', 'python', 'r']
# 643928                                               None
# 293326  ['java', 'scala', 'python', 'assembly', 'sql',...
# 483321                  ['r', 'python', 'sql', 'tableau']
# 531930  ['bash', 'powershell', 'azure', 'linux', 'gith...
# 674784                            ['sql', 'r', 'tableau']
# 607379  ['r', 'python', 'c++', 'crystal', 'oracle', 'p...
# 577553                                   ['sql', 'mysql']
# 757538                                               None
#
#                                           job_type_skills
# 135025  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 538285            {'programming': ['sql', 'python', 'r']}
# 643928                                               None
# 293326  {'cloud': ['aws', 'redshift', 'snowflake', 'az...
# 483321  {'analyst_tools': ['tableau'], 'programming': ...
# 531930  {'async': ['confluence'], 'cloud': ['azure'], ...
# 674784  {'analyst_tools': ['tableau'], 'programming': ...
# 607379  {'analyst_tools': ['visio', 'ms access'], 'clo...
# 577553   {'databases': ['mysql'], 'programming': ['sql']}
# 757538                                               None
