# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()
df_altered = df_original.copy()

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_altered.sample(10)
# Out:
#               job_title_short                                 job_title  \
# 676686         Cloud Engineer                         Delivery Engineer
# 507584          Data Engineer                          BI Data Engineer
# 381527           Data Analyst            Privacy Data Analyst- (remote)
# 330282           Data Analyst                              Data Analyst
# 447854         Data Scientist        Data Scientist KLM|BCG Partnership
# 134790      Software Engineer                      Full Stack Developer
# 110914  Senior Data Scientist           Senior Data Scientist, Delivery
# 481927          Data Engineer                       Data Engineer Azure
# 540681          Data Engineer  Data Engineer Advanced Analytics (m/w/d)
# 566077           Data Analyst    Data Analytics Training and Internship
#
#                  job_location          job_via job_schedule_type  \
# 676686             Lima, Peru   via BeBee Perú         Full-time
# 507584        Porto, Portugal     via LinkedIn         Full-time
# 381527              Plano, TX    via Cognizant         Full-time
# 330282      Las Condes, Chile         via AIRA         Full-time
# 447854  Schiphol, Netherlands     via LinkedIn         Full-time
# 134790       Rivas, Nicaragua    via AngelList         Full-time
# 110914        Berlin, Germany  via Recruit.net         Full-time
# 481927               Anywhere     via LinkedIn         Full-time
# 540681       Mülheim, Germany         via XING         Full-time
# 566077               Anywhere     via LinkedIn              None
#
#         job_work_from_home       search_location      job_posted_date  \
# 676686               False                  Peru  2023-07-20 10:52:39
# 507584               False              Portugal  2023-02-06 11:39:48
# 381527               False  Texas, United States  2023-01-09 18:01:27
# 330282               False                 Chile  2023-12-01 23:32:27
# 447854               False           Netherlands  2023-06-06 14:17:39
# 134790               False             Nicaragua  2023-02-21 09:38:18
# 110914               False               Germany  2023-05-01 00:17:32
# 481927                True                 Spain  2023-04-17 14:18:19
# 540681               False               Germany  2023-02-15 19:34:44
# 566077                True                 Italy  2023-02-23 04:37:44
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 676686                  False                 False           Peru
# 507584                  False                 False       Portugal
# 381527                  False                  True  United States
# 330282                   True                 False          Chile
# 447854                  False                 False    Netherlands
# 134790                   True                 False      Nicaragua
# 110914                  False                 False        Germany
# 481927                   True                 False          Spain
# 540681                   True                 False        Germany
# 566077                  False                 False          Italy
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 676686        None         115000.0              NaN
# 507584        None         115000.0              NaN
# 381527        None         115000.0              NaN
# 330282        None         115000.0              NaN
# 447854        None         115000.0              NaN
# 134790        None         115000.0              NaN
# 110914        None         115000.0              NaN
# 481927        None         115000.0              NaN
# 540681        None         115000.0              NaN
# 566077        None         115000.0              NaN
#
#                                              company_name  \
# 676686                                           Noventiq
# 507584                           AIMS International Spain
# 381527  Cognizant United States, Cognizant Technology ...
# 330282                                      Sodimac Chile
# 447854                                                KLM
# 134790                                Diagnostic Robotics
# 110914                                    Bolt Technology
# 481927                                      M> Consulting
# 540681                                           ALDI SÜD
# 566077                                              OESON
#
#                                                job_skills  \
# 676686                                        ['windows']
# 507584              ['sql', 'python', 't-sql', 'tableau']
# 381527                                  ['excel', 'flow']
# 330282                                            ['sql']
# 447854                                         ['python']
# 134790  ['python', 'aws', 'react', 'kubernetes', 'dock...
# 110914  ['python', 'aws', 'azure', 'airflow', 'spark',...
# 481927  ['sql', 'python', 'azure', 'databricks', 'powe...
# 540681  ['sql', 'python', 'scala', 'nosql', 'sql serve...
# 566077                                   ['sql', 'excel']
#
#                                           job_type_skills
# 676686                                {'os': ['windows']}
# 507584  {'analyst_tools': ['tableau'], 'programming': ...
# 381527    {'analyst_tools': ['excel'], 'other': ['flow']}
# 330282                           {'programming': ['sql']}
# 447854                        {'programming': ['python']}
# 134790  {'cloud': ['aws'], 'libraries': ['react'], 'ot...
# 110914  {'cloud': ['aws', 'azure'], 'libraries': ['air...
# 481927  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 540681  {'cloud': ['databricks'], 'databases': ['sql s...
# 566077  {'analyst_tools': ['excel'], 'programming': ['...
